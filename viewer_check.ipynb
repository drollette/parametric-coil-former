# %% [markdown]
# # CadQuery Viewer Check
#
# A quick sanity check that CadQuery and jupyter-cadquery are working in this Binder environment.

# %%
import cadquery as cq
from jupyter_cadquery import show

# %%
# Create a simple box
box = cq.Workplane("XY").box(10, 20, 30)

show(box)
